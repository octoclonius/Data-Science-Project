# %%
import sqlite3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.manifold import TSNE

# %%
conn = sqlite3.connect('spotify.sqlite')
cursor = conn.cursor()
query = "SELECT name FROM sqlite_master WHERE type='table';"
cursor.execute(query)
tables = cursor.fetchall()
print("List of tables in the database:")
for table in tables:
    print(table[0])
# Out:
# List of tables in the database:
# albums
# artists
# audio_features
# genres
# r_albums_artists
# r_albums_tracks
# r_artist_genre
# r_track_artist
# tracks
# artists_indexed
# albums_indexed
# tracks_indexed
# audio_features_indexed

# %%
query = "SELECT * FROM tracks"
encoding = "latin1"
conn.text_factory = lambda x: str(x, encoding)
track_df = pd.read_sql_query(query, conn)
print(track_df)
# Out:
#                              id  disc_number  duration  explicit  \
# 0        1dizvxctg9dHEyaYTFufVi            1    275893         1
# 1        2g8HN35AnVGIk7B8yMucww            1    252746         1
# 2        49pnyECzcMGCKAqxfTB4JZ            3    315080         0
# 3        4E5IFAXCob6QqZaJMTw5YN            1    240800         1
# 4        1gSt2UlC7mtRtJIc5zqKWn            2    203666         0
# ...                         ...          ...       ...       ...
# 8741667  12S1TA13KXl13sCQZgtI5y            1    198000         0
# 8741668  134MLEMX0AWp5kbMMf90f8            1    191360         0
# 8741669  13WVJaMn0ztUCU8UFCKQFO            1    272572         0
# 8741670  11SfAvTgnEEYy4Ef0fyFpE            1    237200         1
# 8741671  13EW51DKru044OJDJ9Bm8o            1    153147         1
#
#                audio_feature_id  \
# 0        1dizvxctg9dHEyaYTFufVi
# 1        2g8HN35AnVGIk7B8yMucww
# 2        49pnyECzcMGCKAqxfTB4JZ
# 3        4E5IFAXCob6QqZaJMTw5YN
# 4        1gSt2UlC7mtRtJIc5zqKWn
# ...                         ...
# 8741667  12S1TA13KXl13sCQZgtI5y
# 8741668  134MLEMX0AWp5kbMMf90f8
# 8741669  13WVJaMn0ztUCU8UFCKQFO
# 8741670  11SfAvTgnEEYy4Ef0fyFpE
# 8741671  13EW51DKru044OJDJ9Bm8o
#
#                                                       name  \
# 0                    Gz And Hustlas (feat. Nancy Fletcher)
# 1                                Big Poppa - 2005 Remaster
# 2        You Were Born - Early Version Of "One Of The T...
# 3                                      Poppin' Them Thangs
# 4                    It's Hard To Say "I Do", When I Don't
# ...                                                    ...
# 8741667                                   Dime (Unplugged)
# 8741668                                 You Done Fucked Up
# 8741669  Again (ASOT 770) [Future Favorite] - Andrew Ra...
# 8741670                                 Sound Is Vibration
# 8741671  TRAGIC (feat. Youngboy Never Broke Again & Int...
#
#                                                preview_url  track_number  \
# 0                                                                     12
# 1        https://p.scdn.co/mp3-preview/770e023eb0318270...            13
# 2                                                                      6
# 3        https://p.scdn.co/mp3-preview/f3b556ced9657f89...             2
# 4                                                                      2
# ...                                                    ...           ...
# 8741667  https://p.scdn.co/mp3-preview/338399db9ca74488...             6
# 8741668  https://p.scdn.co/mp3-preview/3920a3e0e64de14f...            15
# 8741669  https://p.scdn.co/mp3-preview/e50bbeb308c9a292...            15
# 8741670  https://p.scdn.co/mp3-preview/97fd7c0fb307e3e0...             9
# 8741671  https://p.scdn.co/mp3-preview/49a5adcb57d1f767...             3
#
#          popularity  is_playable
# 0                 0          NaN
# 1                77          NaN
# 2                 8          1.0
# 3                70          NaN
# 4                50          NaN
# ...             ...          ...
# 8741667          12          NaN
# 8741668          17          NaN
# 8741669           5          NaN
# 8741670          52          NaN
# 8741671          81          NaN
#
# [8741672 rows x 10 columns]

# %%
track_sorted_df = track_df.sort_values(by='popularity', ascending=False)
track_sorted_df
# Out:
#                              id  disc_number  duration  explicit  \
# 802846   4iJyoBOLtHqaGxP12qzhQI            1    198081         1
# 109193   7lPN2DXiMsVn7XUKtOW1CS            1    242013         1
# 6202114  3VqeTFIvhxu3DIe4eZVzGq            1    164441         0
# 4025933  67BtfxlNbhBmCDR2L2l8qd            1    137875         1
# 613929   3BZEcbdtXQSo7OrvKRJ6mb            1    137875         1
# ...                         ...          ...       ...       ...
# 4668250  0QLCx9hQIILb8OmrqeF75q            1    327610         1
# 4668247  1xSwsAa29i5iHQlIUDNVY7            1    261154         1
# 4668245  1fyCuwobAvxr8q0TU8jdNs            1    288740         1
# 323081   18qyGR3v4026xRQQnDru8o            1    206336         0
# 0        1dizvxctg9dHEyaYTFufVi            1    275893         1
#
#                audio_feature_id                                        name  \
# 802846   4iJyoBOLtHqaGxP12qzhQI      Peaches (feat. Daniel Caesar & Giveon)
# 109193   7lPN2DXiMsVn7XUKtOW1CS                             drivers license
# 6202114  3VqeTFIvhxu3DIe4eZVzGq                                      Butter
# 4025933  67BtfxlNbhBmCDR2L2l8qd              MONTERO (Call Me By Your Name)
# 613929   3BZEcbdtXQSo7OrvKRJ6mb              MONTERO (Call Me By Your Name)
# ...                         ...                                         ...
# 4668250  0QLCx9hQIILb8OmrqeF75q                                  Dame Micro
# 4668247  1xSwsAa29i5iHQlIUDNVY7                             No Tiene Huesos
# 4668245  1fyCuwobAvxr8q0TU8jdNs                                     Gracias
# 323081   18qyGR3v4026xRQQnDru8o  Eenie Meenie (George Gershwin Arrangement)
# 0        1dizvxctg9dHEyaYTFufVi       Gz And Hustlas (feat. Nancy Fletcher)
#
#                                                preview_url  track_number  \
# 802846                                                                12
# 109193                                                                 1
# 6202114                                                                1
# 4025933  https://p.scdn.co/mp3-preview/fee76abaab413004...             1
# 613929                                                                 1
# ...                                                    ...           ...
# 4668250                                                                9
# 4668247                                                               10
# 4668245                                                                3
# 323081   https://p.scdn.co/mp3-preview/bc2087efdba03530...             7
# 0                                                                     12
#
#          popularity  is_playable
# 802846          100          NaN
# 109193          100          NaN
# 6202114         100          NaN
# 4025933          99          NaN
# 613929           99          NaN
# ...             ...          ...
# 4668250           0          NaN
# 4668247           0          NaN
# 4668245           0          NaN
# 323081            0          NaN
# 0                 0          NaN
#
# [8741672 rows x 10 columns]

# %%
top_df = track_sorted_df.head(10000)
top_df
# Out:
#                              id  disc_number  duration  explicit  \
# 802846   4iJyoBOLtHqaGxP12qzhQI            1    198081         1
# 109193   7lPN2DXiMsVn7XUKtOW1CS            1    242013         1
# 6202114  3VqeTFIvhxu3DIe4eZVzGq            1    164441         0
# 4025933  67BtfxlNbhBmCDR2L2l8qd            1    137875         1
# 613929   3BZEcbdtXQSo7OrvKRJ6mb            1    137875         1
# ...                         ...          ...       ...       ...
# 1944958  3WcWRr8wIkwPQOTYBWjEGf            1    244306         0
# 1945150  1F1QmI8TMHir9SUFrooq5F            1    215384         1
# 2987221  7FIkmLlwTJCK3CXrNIwXXX            1    193044         1
# 72943    69QIVIjPMnI1ABLBqh9P1b            1    260666         0
# 292532   7BxJz17EyAHjZlHEEqrtm6            1    282126         0
#
#                audio_feature_id                                    name  \
# 802846   4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 109193   7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 6202114  3VqeTFIvhxu3DIe4eZVzGq                                  Butter
# 4025933  67BtfxlNbhBmCDR2L2l8qd          MONTERO (Call Me By Your Name)
# 613929   3BZEcbdtXQSo7OrvKRJ6mb          MONTERO (Call Me By Your Name)
# ...                         ...                                     ...
# 1944958  3WcWRr8wIkwPQOTYBWjEGf                     Potevi fare di piÃ¹
# 1945150  1F1QmI8TMHir9SUFrooq5F                               Buff Baby
# 2987221  7FIkmLlwTJCK3CXrNIwXXX                         Bis ich tot bin
# 72943    69QIVIjPMnI1ABLBqh9P1b                                 Twisted
# 292532   7BxJz17EyAHjZlHEEqrtm6                           Eighth Wonder
#
#                                                preview_url  track_number  \
# 802846                                                                12
# 109193                                                                 1
# 6202114                                                                1
# 4025933  https://p.scdn.co/mp3-preview/fee76abaab413004...             1
# 613929                                                                 1
# ...                                                    ...           ...
# 1944958  https://p.scdn.co/mp3-preview/179164f8b2612b21...             1
# 1945150  https://p.scdn.co/mp3-preview/df80e5a8c9e38a8e...             2
# 2987221                                                                1
# 72943    https://p.scdn.co/mp3-preview/d7373f83c11623d3...             1
# 292532   https://p.scdn.co/mp3-preview/0c5a4b6cfdc5d15e...             7
#
#          popularity  is_playable
# 802846          100          NaN
# 109193          100          NaN
# 6202114         100          NaN
# 4025933          99          NaN
# 613929           99          NaN
# ...             ...          ...
# 1944958          67          NaN
# 1945150          67          NaN
# 2987221          67          NaN
# 72943            67          NaN
# 292532           67          NaN
#
# [10000 rows x 10 columns]

# %%
query = "SELECT * FROM audio_features"
encoding = "latin1"
conn.text_factory = lambda x: str(x, encoding)
features_df = pd.read_sql_query(query, conn)
print(features_df)
# Out:
#                              id  acousticness  \
# 0        2jKoVlU7VAmExKJ1Jh3w9P        0.1800
# 1        4JYUDRtPZuVNi7FAnbHyux        0.2720
# 2        6YjKAkDYmlasMqYw73iB0w        0.0783
# 3        2YlvHjDb4Tyxl4A1IcDhAe        0.5840
# 4        3UOuBNEin5peSRqdzvlnWM        0.1700
# ...                         ...           ...
# 8740038  7xq5qTqdCvTQJomW9I5pSZ        0.1430
# 8740039  6ClotRUApTN25L3OnkzQjb        0.0417
# 8740040  7mZL8mtlavFzAzIlIfOMv2        0.2570
# 8740041  08ITn8qaxbnEyk3N08IC47        0.0361
# 8740042  5Vqgrz2M1m49PRh2eR9et7        0.1510
#
#                                               analysis_url  danceability  \
# 0        https://api.spotify.com/v1/audio-analysis/2jKo...         0.893
# 1        https://api.spotify.com/v1/audio-analysis/4JYU...         0.520
# 2        https://api.spotify.com/v1/audio-analysis/6YjK...         0.918
# 3        https://api.spotify.com/v1/audio-analysis/2Ylv...         0.877
# 4        https://api.spotify.com/v1/audio-analysis/3UOu...         0.814
# ...                                                    ...           ...
# 8740038  https://api.spotify.com/v1/audio-analysis/7xq5...         0.649
# 8740039  https://api.spotify.com/v1/audio-analysis/6Clo...         0.739
# 8740040  https://api.spotify.com/v1/audio-analysis/7mZL...         0.814
# 8740041  https://api.spotify.com/v1/audio-analysis/08IT...         0.644
# 8740042  https://api.spotify.com/v1/audio-analysis/5Vqg...         0.806
#
#          duration  energy  instrumentalness  key  liveness  loudness  mode  \
# 0          219160   0.514          0.000000   11    0.0596    -5.080     1
# 1          302013   0.847          0.000000    9    0.3250    -5.300     1
# 2          288200   0.586          0.000000    1    0.1450    -2.890     1
# 3          243013   0.681          0.000000    1    0.1190    -6.277     0
# 4          270667   0.781          0.000518   11    0.0520    -3.330     1
# ...           ...     ...               ...  ...       ...       ...   ...
# 8740038    184000   0.437          0.726000    2    0.1210   -12.310     1
# 8740039    237582   0.702          0.795000    4    0.3640    -7.966     1
# 8740040    170329   0.626          0.377000    7    0.1240    -7.212     0
# 8740041    199300   0.610          0.935000    0    0.1090    -5.380     1
# 8740042    240000   0.535          0.000101    9    0.0812    -7.169     1
#
#          speechiness       tempo  time_signature  valence
# 0             0.2830   95.848000               4    0.787
# 1             0.4270  177.371002               4    0.799
# 2             0.1330   95.516998               4    0.779
# 3             0.2590   94.834999               4    0.839
# 4             0.2330   93.445000               4    0.536
# ...              ...         ...             ...      ...
# 8740038       0.0729  149.998001               4    0.164
# 8740039       0.1310   94.977997               4    0.554
# 8740040       0.3320   92.954002               4    0.617
# 8740041       0.0462   94.015999               4    0.438
# 8740042       0.0927   89.998001               4    0.798
#
# [8740043 rows x 15 columns]

# %%
track_and_features_df = pd.merge(top_df, features_df, on='id', how='inner')

# %% [raw]
# track_and_features_df.drop(columns=["audio_feature_id"], inplace=True)

# %%
track_and_features_df
# Out:
#                           id  disc_number  duration_x  explicit  \
# 0     4iJyoBOLtHqaGxP12qzhQI            1      198081         1
# 1     7lPN2DXiMsVn7XUKtOW1CS            1      242013         1
# 2     3VqeTFIvhxu3DIe4eZVzGq            1      164441         0
# 3     67BtfxlNbhBmCDR2L2l8qd            1      137875         1
# 4     3BZEcbdtXQSo7OrvKRJ6mb            1      137875         1
# ...                      ...          ...         ...       ...
# 9994  3WcWRr8wIkwPQOTYBWjEGf            1      244306         0
# 9995  1F1QmI8TMHir9SUFrooq5F            1      215384         1
# 9996  7FIkmLlwTJCK3CXrNIwXXX            1      193044         1
# 9997  69QIVIjPMnI1ABLBqh9P1b            1      260666         0
# 9998  7BxJz17EyAHjZlHEEqrtm6            1      282126         0
#
#             audio_feature_id                                    name  \
# 0     4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 1     7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 2     3VqeTFIvhxu3DIe4eZVzGq                                  Butter
# 3     67BtfxlNbhBmCDR2L2l8qd          MONTERO (Call Me By Your Name)
# 4     3BZEcbdtXQSo7OrvKRJ6mb          MONTERO (Call Me By Your Name)
# ...                      ...                                     ...
# 9994  3WcWRr8wIkwPQOTYBWjEGf                     Potevi fare di piÃ¹
# 9995  1F1QmI8TMHir9SUFrooq5F                               Buff Baby
# 9996  7FIkmLlwTJCK3CXrNIwXXX                         Bis ich tot bin
# 9997  69QIVIjPMnI1ABLBqh9P1b                                 Twisted
# 9998  7BxJz17EyAHjZlHEEqrtm6                           Eighth Wonder
#
#                                             preview_url  track_number  \
# 0                                                                  12
# 1                                                                   1
# 2                                                                   1
# 3     https://p.scdn.co/mp3-preview/fee76abaab413004...             1
# 4                                                                   1
# ...                                                 ...           ...
# 9994  https://p.scdn.co/mp3-preview/179164f8b2612b21...             1
# 9995  https://p.scdn.co/mp3-preview/df80e5a8c9e38a8e...             2
# 9996                                                                1
# 9997  https://p.scdn.co/mp3-preview/d7373f83c11623d3...             1
# 9998  https://p.scdn.co/mp3-preview/0c5a4b6cfdc5d15e...             7
#
#       popularity  is_playable  ...  energy instrumentalness  key  liveness  \
# 0            100          NaN  ...   0.696         0.000000    0    0.4200
# 1            100          NaN  ...   0.436         0.000013   10    0.1050
# 2            100          NaN  ...   0.459         0.000000    8    0.0906
# 3             99          NaN  ...   0.508         0.000000    8    0.3840
# 4             99          NaN  ...   0.508         0.000000    8    0.3840
# ...          ...          ...  ...     ...              ...  ...       ...
# 9994          67          NaN  ...   0.391         0.000000    4    0.0906
# 9995          67          NaN  ...   0.765         0.000000    5    0.1010
# 9996          67          NaN  ...   0.503         0.000000    0    0.2150
# 9997          67          NaN  ...   0.514         0.000000   11    0.2480
# 9998          67          NaN  ...   0.680         0.398000    2    0.1440
#
#       loudness  mode  speechiness       tempo  time_signature  valence
# 0       -6.181     1       0.1190   90.029999               4    0.464
# 1       -8.761     1       0.0601  143.873993               4    0.132
# 2       -5.187     1       0.0948  109.997002               4    0.695
# 3       -6.682     0       0.1520  178.817993               4    0.758
# 4       -6.682     0       0.1520  178.817993               4    0.758
# ...        ...   ...          ...         ...             ...      ...
# 9994    -8.317     1       0.0559  123.705002               4    0.162
# 9995    -6.047     1       0.0571  156.039993               4    0.512
# 9996    -7.906     0       0.0816  139.011993               4    0.388
# 9997    -9.759     1       0.0466  175.848999               4    0.822
# 9998    -8.143     0       0.0328  139.983994               4    0.640
#
# [9999 rows x 24 columns]

# %%
print(track_and_features_df.columns)
# Out:
# Index(['id', 'disc_number', 'duration_x', 'explicit', 'audio_feature_id',
#        'name', 'preview_url', 'track_number', 'popularity', 'is_playable',
#        'acousticness', 'analysis_url', 'danceability', 'duration_y', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %%
query = "SELECT * FROM r_track_artist"
encoding = "latin1"
conn.text_factory = lambda x: str(x, encoding)
r_track_artist_df = pd.read_sql_query(query, conn)
print(r_track_artist_df)
# Out:
#                         track_id               artist_id
# 0         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# 1         2jKoVlU7VAmExKJ1Jh3w9P  2VX0o9LDIVmKIgpnwdJpOJ
# 2         2jKoVlU7VAmExKJ1Jh3w9P  3iBOsmwGzRKyR0vs2I61xP
# 3         2jKoVlU7VAmExKJ1Jh3w9P  22qf8cJRzBjIWb2Jc4JeOr
# 4         4JYUDRtPZuVNi7FAnbHyux  4akj4uteQQrrGxhX9Rjuyf
# ...                          ...                     ...
# 11840397  6ClotRUApTN25L3OnkzQjb  3y9hQYlwNKqhdybIJTFzTr
# 11840398  7mZL8mtlavFzAzIlIfOMv2  5e8vdggiGg9glSpuBgcaiv
# 11840399  7mZL8mtlavFzAzIlIfOMv2  6NgwMiz1Dwsktnn8p8yujE
# 11840400  08ITn8qaxbnEyk3N08IC47  4NEA8zkFgdVHYWZXANEHA7
# 11840401  5Vqgrz2M1m49PRh2eR9et7  4LOzEceyTOhRzbpebCciHR
#
# [11840402 rows x 2 columns]

# %%
query = "SELECT * FROM r_artist_genre"
encoding = "latin1"
conn.text_factory = lambda x: str(x, encoding)
artist_genre_df = pd.read_sql_query(query, conn)
print(artist_genre_df)
# Out:
#                     genre_id               artist_id
# 0            detroit hip hop  4tujQJicOnuZRLiBFdp3Ou
# 1                     g funk  4tujQJicOnuZRLiBFdp3Ou
# 2               gangster rap  4tujQJicOnuZRLiBFdp3Ou
# 3           hardcore hip hop  4tujQJicOnuZRLiBFdp3Ou
# 4                    hip hop  4tujQJicOnuZRLiBFdp3Ou
# ...                      ...                     ...
# 487381                   edm  05KDKIpxshxrB9BMewaCBW
# 487382                   edm  6nS5roXSAGhTGr34W6n7Et
# 487383          samurai trap  5rcAoYM8NZrlnPZES9S8KV
# 487384           focus beats  0XBtKvTff8E8BIhtlxjVHv
# 487385  hip-hop experimental  6NgwMiz1Dwsktnn8p8yujE
#
# [487386 rows x 2 columns]

# %%
r_track_artist_df = pd.merge(r_track_artist_df, artist_genre_df, on='artist_id', how='inner')
r_track_artist_df
# Out:
#                         track_id               artist_id  \
# 0         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# 1         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# 2         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# 3         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# 4         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# ...                          ...                     ...
# 21678565  6Q42I6v0BiF8pzg9ELOX2m  5yUWxOhPOP18jZ2TwQxEtw
# 21678566  33tYADyL2aZctrvR59K1bQ  2YEnrpAWWaNRFumgde1lLH
# 21678567  73xL8Khrwd3OWJlBjKSpGk  2YEnrpAWWaNRFumgde1lLH
# 21678568  6oq0MdzLaFShOXXqs2yavp  2YEnrpAWWaNRFumgde1lLH
# 21678569  07k2HmQ9rB1kXT0BbQ0hsS  6X2kWnJXpH8ITqJu0kzVhe
#
#                           genre_id
# 0                  detroit hip hop
# 1                           g funk
# 2                     gangster rap
# 3                 hardcore hip hop
# 4                          hip hop
# ...                            ...
# 21678565  south african deep house
# 21678566               disco house
# 21678567               disco house
# 21678568               disco house
# 21678569               piano house
#
# [21678570 rows x 3 columns]

# %%
query = "SELECT * FROM artists"
encoding = "latin1"
conn.text_factory = lambda x: str(x, encoding)
artists_df = pd.read_sql_query(query, conn)
print(artists_df)
# Out:
#                   name                      id  popularity  followers
# 0               Xzibit  4tujQJicOnuZRLiBFdp3Ou          69    1193665
# 1         Erick Sermon  2VX0o9LDIVmKIgpnwdJpOJ          54     142007
# 2                J. Ro  3iBOsmwGzRKyR0vs2I61xP          45        158
# 3                 Tash  22qf8cJRzBjIWb2Jc4JeOr          48       3421
# 4           Craig Mack  4akj4uteQQrrGxhX9Rjuyf          55     161966
# ...                ...                     ...         ...        ...
# 1066026   Justice Hall  7KcttLT1Ou7ICdL3TUlc5H           0          3
# 1066027    Miss Malibu  68bLTKJw7zEdzEsJZS1As0           0          2
# 1066028     Jam'addict  0VzXnkUTwKDYznbgEvn3Ca          50        283
# 1066029         Sohaib  78hHMThaOCqyAGfytBUwGs           3          4
# 1066030  Carter Haugen  1c6IP1ctsxmIkgRToTzRXY           3          4
#
# [1066031 rows x 4 columns]

# %%
artists_df.rename(columns={'id': 'artist_id'}, inplace=True)
r_track_artist_merged_df = pd.merge(r_track_artist_df, artists_df[["name", "artist_id"]], on='artist_id', how='inner')

# %%
r_track_artist_merged_df
# Out:
#                         track_id               artist_id  \
# 0         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# 1         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# 2         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# 3         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# 4         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# ...                          ...                     ...
# 21678565  6Q42I6v0BiF8pzg9ELOX2m  5yUWxOhPOP18jZ2TwQxEtw
# 21678566  33tYADyL2aZctrvR59K1bQ  2YEnrpAWWaNRFumgde1lLH
# 21678567  73xL8Khrwd3OWJlBjKSpGk  2YEnrpAWWaNRFumgde1lLH
# 21678568  6oq0MdzLaFShOXXqs2yavp  2YEnrpAWWaNRFumgde1lLH
# 21678569  07k2HmQ9rB1kXT0BbQ0hsS  6X2kWnJXpH8ITqJu0kzVhe
#
#                           genre_id            name
# 0                  detroit hip hop          Xzibit
# 1                           g funk          Xzibit
# 2                     gangster rap          Xzibit
# 3                 hardcore hip hop          Xzibit
# 4                          hip hop          Xzibit
# ...                            ...             ...
# 21678565  south african deep house          SONIDO
# 21678566               disco house    Oden & Fatzo
# 21678567               disco house    Oden & Fatzo
# 21678568               disco house    Oden & Fatzo
# 21678569               piano house  Edward's World
#
# [21678570 rows x 4 columns]

# %%
r_track_artist_merged_df
# Out:
#                         track_id               artist_id  \
# 0         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# 1         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# 2         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# 3         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# 4         2jKoVlU7VAmExKJ1Jh3w9P  4tujQJicOnuZRLiBFdp3Ou
# ...                          ...                     ...
# 21678565  6Q42I6v0BiF8pzg9ELOX2m  5yUWxOhPOP18jZ2TwQxEtw
# 21678566  33tYADyL2aZctrvR59K1bQ  2YEnrpAWWaNRFumgde1lLH
# 21678567  73xL8Khrwd3OWJlBjKSpGk  2YEnrpAWWaNRFumgde1lLH
# 21678568  6oq0MdzLaFShOXXqs2yavp  2YEnrpAWWaNRFumgde1lLH
# 21678569  07k2HmQ9rB1kXT0BbQ0hsS  6X2kWnJXpH8ITqJu0kzVhe
#
#                           genre_id            name
# 0                  detroit hip hop          Xzibit
# 1                           g funk          Xzibit
# 2                     gangster rap          Xzibit
# 3                 hardcore hip hop          Xzibit
# 4                          hip hop          Xzibit
# ...                            ...             ...
# 21678565  south african deep house          SONIDO
# 21678566               disco house    Oden & Fatzo
# 21678567               disco house    Oden & Fatzo
# 21678568               disco house    Oden & Fatzo
# 21678569               piano house  Edward's World
#
# [21678570 rows x 4 columns]

# %%
track_and_features_df.rename(columns={'id': 'track_id'}, inplace=True)

# %%
grouped_artists = r_track_artist_merged_df.groupby('track_id')['name'].agg(list).reset_index()

# %%
grouped_artists
# Out:
#                        track_id  \
# 0        0000QBRGPosiFRXKmMYnsO
# 1        0000gBWfr2zIFzE5tDzxca
# 2        0000uJA4xCdxThagdLkkLR
# 3        0001Lyv0YTjkZSqzT4WkLy
# 4        0001QZSdENvrMx6cZXZJdo
# ...                         ...
# 6558498  7zzxqMfB1N7apnN3kuos5v
# 6558499  7zzy0bwJGb8gZ4e6qxPASG
# 6558500  7zzyILZOJRvpWhp7NtJJ51
# 6558501  7zzyNsSXglPKfmyawxn5KP
# 6558502  7zzz9DS4ogGJ2YPlLzENJe
#
#                                                       name
# 0                                       [Sexteto La Playa]
# 1                                          [RattenfÃ¤nger]
# 2               [Cherryholmes, Cherryholmes, Cherryholmes]
# 3        [Half Japanese, Half Japanese, Half Japanese, ...
# 4        [Archers Of Loaf, Archers Of Loaf, Archers Of ...
# ...                                                    ...
# 6558498  [Jonathan Butler, Jonathan Butler, Jonathan Bu...
# 6558499  [Lead Belly, Lead Belly, Lead Belly, Lead Bell...
# 6558500  [03 Greedo, 03 Greedo, 03 Greedo, 03 Greedo, 0...
# 6558501  [John O'Callaghan, John O'Callaghan, John O'Ca...
# 6558502  [Kitchen and the Plastic Spoons, Kitchen and t...
#
# [6558503 rows x 2 columns]

# %%
grouped_genres = r_track_artist_merged_df.groupby('track_id')['genre_id'].agg(list).reset_index()
grouped_genres
# Out:
#                        track_id  \
# 0        0000QBRGPosiFRXKmMYnsO
# 1        0000gBWfr2zIFzE5tDzxca
# 2        0000uJA4xCdxThagdLkkLR
# 3        0001Lyv0YTjkZSqzT4WkLy
# 4        0001QZSdENvrMx6cZXZJdo
# ...                         ...
# 6558498  7zzxqMfB1N7apnN3kuos5v
# 6558499  7zzy0bwJGb8gZ4e6qxPASG
# 6558500  7zzyILZOJRvpWhp7NtJJ51
# 6558501  7zzyNsSXglPKfmyawxn5KP
# 6558502  7zzz9DS4ogGJ2YPlLzENJe
#
#                                                   genre_id
# 0                                            [cha-cha-cha]
# 1                                        [ukrainian metal]
# 2        [bluegrass, neo-traditional bluegrass, progres...
# 3        [dunedin sound, experimental, experimental ind...
# 4        [alternative pop, alternative rock, emo, gbvfi...
# ...                                                    ...
# 6558498  [smooth jazz, smooth saxophone, south african ...
# 6558499  [acoustic blues, appalachian folk, blues, coun...
# 6558500  [cali rap, melodic rap, trap, underground hip ...
# 6558501  [edm, pop dance, progressive house, progressiv...
# 6558502  [gothic post-punk, minimal wave, swedish post-...
#
# [6558503 rows x 2 columns]

# %%
merged_artists_df = pd.merge(grouped_artists, grouped_genres, on='track_id', how='inner')
merged_artists_df
# Out:
#                        track_id  \
# 0        0000QBRGPosiFRXKmMYnsO
# 1        0000gBWfr2zIFzE5tDzxca
# 2        0000uJA4xCdxThagdLkkLR
# 3        0001Lyv0YTjkZSqzT4WkLy
# 4        0001QZSdENvrMx6cZXZJdo
# ...                         ...
# 6558498  7zzxqMfB1N7apnN3kuos5v
# 6558499  7zzy0bwJGb8gZ4e6qxPASG
# 6558500  7zzyILZOJRvpWhp7NtJJ51
# 6558501  7zzyNsSXglPKfmyawxn5KP
# 6558502  7zzz9DS4ogGJ2YPlLzENJe
#
#                                                       name  \
# 0                                       [Sexteto La Playa]
# 1                                          [RattenfÃ¤nger]
# 2               [Cherryholmes, Cherryholmes, Cherryholmes]
# 3        [Half Japanese, Half Japanese, Half Japanese, ...
# 4        [Archers Of Loaf, Archers Of Loaf, Archers Of ...
# ...                                                    ...
# 6558498  [Jonathan Butler, Jonathan Butler, Jonathan Bu...
# 6558499  [Lead Belly, Lead Belly, Lead Belly, Lead Bell...
# 6558500  [03 Greedo, 03 Greedo, 03 Greedo, 03 Greedo, 0...
# 6558501  [John O'Callaghan, John O'Callaghan, John O'Ca...
# 6558502  [Kitchen and the Plastic Spoons, Kitchen and t...
#
#                                                   genre_id
# 0                                            [cha-cha-cha]
# 1                                        [ukrainian metal]
# 2        [bluegrass, neo-traditional bluegrass, progres...
# 3        [dunedin sound, experimental, experimental ind...
# 4        [alternative pop, alternative rock, emo, gbvfi...
# ...                                                    ...
# 6558498  [smooth jazz, smooth saxophone, south african ...
# 6558499  [acoustic blues, appalachian folk, blues, coun...
# 6558500  [cali rap, melodic rap, trap, underground hip ...
# 6558501  [edm, pop dance, progressive house, progressiv...
# 6558502  [gothic post-punk, minimal wave, swedish post-...
#
# [6558503 rows x 3 columns]

# %%
all_df = pd.merge(track_and_features_df, merged_artists_df, on='track_id', how='inner')
all_df
# Out:
#                     track_id  disc_number  duration_x  explicit  \
# 0     4iJyoBOLtHqaGxP12qzhQI            1      198081         1
# 1     7lPN2DXiMsVn7XUKtOW1CS            1      242013         1
# 2     3VqeTFIvhxu3DIe4eZVzGq            1      164441         0
# 3     67BtfxlNbhBmCDR2L2l8qd            1      137875         1
# 4     3BZEcbdtXQSo7OrvKRJ6mb            1      137875         1
# ...                      ...          ...         ...       ...
# 9819  3WcWRr8wIkwPQOTYBWjEGf            1      244306         0
# 9820  1F1QmI8TMHir9SUFrooq5F            1      215384         1
# 9821  7FIkmLlwTJCK3CXrNIwXXX            1      193044         1
# 9822  69QIVIjPMnI1ABLBqh9P1b            1      260666         0
# 9823  7BxJz17EyAHjZlHEEqrtm6            1      282126         0
#
#             audio_feature_id                                  name_x  \
# 0     4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 1     7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 2     3VqeTFIvhxu3DIe4eZVzGq                                  Butter
# 3     67BtfxlNbhBmCDR2L2l8qd          MONTERO (Call Me By Your Name)
# 4     3BZEcbdtXQSo7OrvKRJ6mb          MONTERO (Call Me By Your Name)
# ...                      ...                                     ...
# 9819  3WcWRr8wIkwPQOTYBWjEGf                     Potevi fare di piÃ¹
# 9820  1F1QmI8TMHir9SUFrooq5F                               Buff Baby
# 9821  7FIkmLlwTJCK3CXrNIwXXX                         Bis ich tot bin
# 9822  69QIVIjPMnI1ABLBqh9P1b                                 Twisted
# 9823  7BxJz17EyAHjZlHEEqrtm6                           Eighth Wonder
#
#                                             preview_url  track_number  \
# 0                                                                  12
# 1                                                                   1
# 2                                                                   1
# 3     https://p.scdn.co/mp3-preview/fee76abaab413004...             1
# 4                                                                   1
# ...                                                 ...           ...
# 9819  https://p.scdn.co/mp3-preview/179164f8b2612b21...             1
# 9820  https://p.scdn.co/mp3-preview/df80e5a8c9e38a8e...             2
# 9821                                                                1
# 9822  https://p.scdn.co/mp3-preview/d7373f83c11623d3...             1
# 9823  https://p.scdn.co/mp3-preview/0c5a4b6cfdc5d15e...             7
#
#       popularity  is_playable  ...  key liveness  loudness  mode  speechiness  \
# 0            100          NaN  ...    0   0.4200    -6.181     1       0.1190
# 1            100          NaN  ...   10   0.1050    -8.761     1       0.0601
# 2            100          NaN  ...    8   0.0906    -5.187     1       0.0948
# 3             99          NaN  ...    8   0.3840    -6.682     0       0.1520
# 4             99          NaN  ...    8   0.3840    -6.682     0       0.1520
# ...          ...          ...  ...  ...      ...       ...   ...          ...
# 9819          67          NaN  ...    4   0.0906    -8.317     1       0.0559
# 9820          67          NaN  ...    5   0.1010    -6.047     1       0.0571
# 9821          67          NaN  ...    0   0.2150    -7.906     0       0.0816
# 9822          67          NaN  ...   11   0.2480    -9.759     1       0.0466
# 9823          67          NaN  ...    2   0.1440    -8.143     0       0.0328
#
#            tempo  time_signature  valence  \
# 0      90.029999               4    0.464
# 1     143.873993               4    0.132
# 2     109.997002               4    0.695
# 3     178.817993               4    0.758
# 4     178.817993               4    0.758
# ...          ...             ...      ...
# 9819  123.705002               4    0.162
# 9820  156.039993               4    0.512
# 9821  139.011993               4    0.388
# 9822  175.848999               4    0.822
# 9823  139.983994               4    0.640
#
#                                                  name_y  \
# 0     [Justin Bieber, Justin Bieber, Justin Bieber, ...
# 1      [Olivia Rodrigo, Olivia Rodrigo, Olivia Rodrigo]
# 2                                            [BTS, BTS]
# 3          [Lil Nas X, Lil Nas X, Lil Nas X, Lil Nas X]
# 4          [Lil Nas X, Lil Nas X, Lil Nas X, Lil Nas X]
# ...                                                 ...
# 9819                                            [Arisa]
# 9820  [tobi lou, tobi lou, tobi lou, tobi lou, tobi ...
# 9821                         [Jumpa, Jumpa, Zuna, Zuna]
# 9822  [Keith Sweat, Keith Sweat, Keith Sweat, Keith ...
# 9823            [Lemon Demon, Lemon Demon, Lemon Demon]
#
#                                                genre_id
# 0     [canadian pop, pop, post-teen pop, canadian co...
# 1                           [alt z, pop, post-teen pop]
# 2                              [k-pop, k-pop boy group]
# 3     [country rap, lgbtq+ hip hop, pop rap, queer c...
# 4     [country rap, lgbtq+ hip hop, pop rap, queer c...
# ...                                                 ...
# 9819                                [italian adult pop]
# 9820  [alternative r&b, chicago rap, chill r&b, pop,...
# 9821  [luxembourgian hip hop, german hip hop, albani...
# 9822  [funk, hip pop, new jack swing, quiet storm, r...
# 9823                   [comic, indie pop, indietronica]
#
# [9824 rows x 26 columns]

# %%
all_df['name_y'] = all_df['name_y'].apply(lambda x: list(dict.fromkeys(x)))
all_df['genre_id'] = all_df['genre_id'].apply(lambda x: list(dict.fromkeys(x)))
all_df.drop(columns=['duration_y'], inplace=True)
all_df.rename(columns={'name_x': 'name', 'name_y': 'artist', 'duration_x': 'duration'}, inplace=True)
all_df
# Out:
#                     track_id  disc_number  duration  explicit  \
# 0     4iJyoBOLtHqaGxP12qzhQI            1    198081         1
# 1     7lPN2DXiMsVn7XUKtOW1CS            1    242013         1
# 2     3VqeTFIvhxu3DIe4eZVzGq            1    164441         0
# 3     67BtfxlNbhBmCDR2L2l8qd            1    137875         1
# 4     3BZEcbdtXQSo7OrvKRJ6mb            1    137875         1
# ...                      ...          ...       ...       ...
# 9819  3WcWRr8wIkwPQOTYBWjEGf            1    244306         0
# 9820  1F1QmI8TMHir9SUFrooq5F            1    215384         1
# 9821  7FIkmLlwTJCK3CXrNIwXXX            1    193044         1
# 9822  69QIVIjPMnI1ABLBqh9P1b            1    260666         0
# 9823  7BxJz17EyAHjZlHEEqrtm6            1    282126         0
#
#             audio_feature_id                                    name  \
# 0     4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 1     7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 2     3VqeTFIvhxu3DIe4eZVzGq                                  Butter
# 3     67BtfxlNbhBmCDR2L2l8qd          MONTERO (Call Me By Your Name)
# 4     3BZEcbdtXQSo7OrvKRJ6mb          MONTERO (Call Me By Your Name)
# ...                      ...                                     ...
# 9819  3WcWRr8wIkwPQOTYBWjEGf                     Potevi fare di piÃ¹
# 9820  1F1QmI8TMHir9SUFrooq5F                               Buff Baby
# 9821  7FIkmLlwTJCK3CXrNIwXXX                         Bis ich tot bin
# 9822  69QIVIjPMnI1ABLBqh9P1b                                 Twisted
# 9823  7BxJz17EyAHjZlHEEqrtm6                           Eighth Wonder
#
#                                             preview_url  track_number  \
# 0                                                                  12
# 1                                                                   1
# 2                                                                   1
# 3     https://p.scdn.co/mp3-preview/fee76abaab413004...             1
# 4                                                                   1
# ...                                                 ...           ...
# 9819  https://p.scdn.co/mp3-preview/179164f8b2612b21...             1
# 9820  https://p.scdn.co/mp3-preview/df80e5a8c9e38a8e...             2
# 9821                                                                1
# 9822  https://p.scdn.co/mp3-preview/d7373f83c11623d3...             1
# 9823  https://p.scdn.co/mp3-preview/0c5a4b6cfdc5d15e...             7
#
#       popularity  is_playable  ...  key liveness  loudness  mode  speechiness  \
# 0            100          NaN  ...    0   0.4200    -6.181     1       0.1190
# 1            100          NaN  ...   10   0.1050    -8.761     1       0.0601
# 2            100          NaN  ...    8   0.0906    -5.187     1       0.0948
# 3             99          NaN  ...    8   0.3840    -6.682     0       0.1520
# 4             99          NaN  ...    8   0.3840    -6.682     0       0.1520
# ...          ...          ...  ...  ...      ...       ...   ...          ...
# 9819          67          NaN  ...    4   0.0906    -8.317     1       0.0559
# 9820          67          NaN  ...    5   0.1010    -6.047     1       0.0571
# 9821          67          NaN  ...    0   0.2150    -7.906     0       0.0816
# 9822          67          NaN  ...   11   0.2480    -9.759     1       0.0466
# 9823          67          NaN  ...    2   0.1440    -8.143     0       0.0328
#
#            tempo  time_signature  valence  \
# 0      90.029999               4    0.464
# 1     143.873993               4    0.132
# 2     109.997002               4    0.695
# 3     178.817993               4    0.758
# 4     178.817993               4    0.758
# ...          ...             ...      ...
# 9819  123.705002               4    0.162
# 9820  156.039993               4    0.512
# 9821  139.011993               4    0.388
# 9822  175.848999               4    0.822
# 9823  139.983994               4    0.640
#
#                                       artist  \
# 0     [Justin Bieber, Daniel Caesar, Giveon]
# 1                           [Olivia Rodrigo]
# 2                                      [BTS]
# 3                                [Lil Nas X]
# 4                                [Lil Nas X]
# ...                                      ...
# 9819                                 [Arisa]
# 9820                              [tobi lou]
# 9821                           [Jumpa, Zuna]
# 9822                           [Keith Sweat]
# 9823                           [Lemon Demon]
#
#                                                genre_id
# 0     [canadian pop, pop, post-teen pop, canadian co...
# 1                           [alt z, pop, post-teen pop]
# 2                              [k-pop, k-pop boy group]
# 3     [country rap, lgbtq+ hip hop, pop rap, queer c...
# 4     [country rap, lgbtq+ hip hop, pop rap, queer c...
# ...                                                 ...
# 9819                                [italian adult pop]
# 9820  [alternative r&b, chicago rap, chill r&b, pop,...
# 9821  [luxembourgian hip hop, german hip hop, albani...
# 9822  [funk, hip pop, new jack swing, quiet storm, r...
# 9823                   [comic, indie pop, indietronica]
#
# [9824 rows x 25 columns]

# %%
all_df.to_csv('top_songs_large.csv', index=False)

# %%
cursor.close()
conn.close()
