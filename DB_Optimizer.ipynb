# %%
import sqlite3
import pandas as pd

# %%
PATH_DB = './spotify.sqlite'
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
con = sqlite3.connect(f'file:{PATH_DB}?mode=ro', uri=True)
df_db = pd.read_sql_query('''
    SELECT
        name, sql
    FROM
        sqlite_master
''', con)
con.close()
# View database before optimization
df_db
# Out:
#                name  \
# 0            albums
# 1           artists
# 2    audio_features
# 3            genres
# 4  r_albums_artists
# 5   r_albums_tracks
# 6    r_artist_genre
# 7    r_track_artist
# 8            tracks
#
#                                                                                                                                                                                                                         sql
# 0                                                                                                                             CREATE TABLE albums ([id], [name], [album_group], [album_type], [release_date], [popularity])
# 1                                                                                                                                                            CREATE TABLE artists ([name], [id], [popularity], [followers])
# 2  CREATE TABLE audio_features ([id], [acousticness], [analysis_url], [danceability], [duration], [energy], [instrumentalness], [key], [liveness], [loudness], [mode], [speechiness], [tempo], [time_signature], [valence])
# 3                                                                                                                                                                                                CREATE TABLE genres ([id])
# 4                                                                                                                                                                   CREATE TABLE r_albums_artists ([album_id], [artist_id])
# 5                                                                                                                                                                     CREATE TABLE r_albums_tracks ([album_id], [track_id])
# 6                                                                                                                                                                     CREATE TABLE r_artist_genre ([genre_id], [artist_id])
# 7                                                                                                                                                                     CREATE TABLE r_track_artist ([track_id], [artist_id])
# 8                                                                 CREATE TABLE tracks ([id], [disc_number], [duration], [explicit], [audio_feature_id], [name], [preview_url], [track_number], [popularity], [is_playable])

# %%
con = sqlite3.connect(PATH_DB)
cur = con.cursor()

print('Resetting database to initial state...')
cur.execute('DROP TABLE IF EXISTS audio_features_indexed')
cur.execute('DROP TABLE IF EXISTS tracks_indexed')
cur.execute('DROP TABLE IF EXISTS albums_indexed')
cur.execute('DROP TABLE IF EXISTS artists_indexed')
con.commit()

# artists_indexed
print('\nartists_indexed')
cur.execute('''
    CREATE TABLE artists_indexed (
        id TEXT PRIMARY KEY,
        name TEXT NOT NULL,
        followers INTEGER,
        popularity INTEGER NOT NULL
    )
''')
print('Copying data...')
cur.execute('''
    INSERT INTO artists_indexed (
        id,
        name,
        followers,
        popularity
    )
    SELECT
        id,
        name,
        followers,
        popularity
    FROM
        artists
''')
print('Indexing table...')
cur.execute('CREATE INDEX idx_artists_indexed_name ON artists_indexed(name)')
cur.execute('CREATE INDEX idx_artists_indexed_followers ON artists_indexed(followers)')
cur.execute('CREATE INDEX idx_artists_indexed_popularity ON artists_indexed(popularity)')
con.commit()

# albums_indexed
print('\nalbums_indexed')
cur.execute('''
    CREATE TABLE albums_indexed (
        id TEXT PRIMARY KEY,
        name TEXT NOT NULL,
        album_type TEXT,
        release_date TEXT,
        popularity INTEGER NOT NULL
    )
''')
print('Copying data...')
cur.execute('''
    INSERT INTO albums_indexed (
        id,
        name,
        album_type,
        release_date,
        popularity
    )
    SELECT
        id,
        name,
        album_type,
        release_date,
        popularity
    FROM
        albums
''')
print('Indexing table...')
cur.execute('CREATE INDEX idx_albums_indexed_name ON albums_indexed(name)')
cur.execute('CREATE INDEX idx_albums_indexed_album_type ON albums_indexed(album_type)')
cur.execute('CREATE INDEX idx_albums_indexed_release_date ON albums_indexed(release_date)')
cur.execute('CREATE INDEX idx_albums_indexed_popularity ON albums_indexed(popularity)')
con.commit()

# tracks_indexed
print('\ntracks_indexed')
cur.execute('''
    CREATE TABLE tracks_indexed (
        id TEXT PRIMARY KEY,
        name TEXT NOT NULL,
        duration INTEGER,
        explicit INTEGER,
        audio_feature_id TEXT NOT NULL,
        popularity INTEGER NOT NULL,
        UNIQUE(audio_feature_id)
    )
''')
print('Copying data...')
cur.execute('''
    INSERT INTO tracks_indexed (
        id,
        name,
        duration,
        explicit,
        audio_feature_id,
        popularity
    )
    SELECT
        tracks.id,
        tracks.name,
        tracks.duration,
        tracks.explicit,
        tracks.audio_feature_id,
        tracks.popularity
    FROM
        tracks
    WHERE
        id = audio_feature_id
''')
print('Indexing table...')
cur.execute('CREATE INDEX idx_tracks_indexed_name ON tracks_indexed(name)')
cur.execute('CREATE INDEX idx_tracks_indexed_duration ON tracks_indexed(duration)')
cur.execute('CREATE INDEX idx_tracks_indexed_explicit ON tracks_indexed(explicit)')
cur.execute('CREATE UNIQUE INDEX idx_tracks_indexed_audio_feature_id ON tracks_indexed(audio_feature_id)')
cur.execute('CREATE INDEX idx_tracks_indexed_popularity ON tracks_indexed(popularity)')
con.commit()

# audio_features_indexed
print('\naudio_features_indexed')
cur.execute('''
    CREATE TABLE audio_features_indexed (
        id TEXT PRIMARY KEY,
        analysis_url TEXT,
        loudness REAL,
        tempo REAL,
        time_signature INTEGER,
        key INTEGER,
        mode INTEGER,
        acousticness REAL,
        danceability REAL,
        energy REAL,
        instrumentalness REAL,
        liveness REAL,
        speechiness REAL,
        valence REAL,
        UNIQUE(analysis_url)
    )
''')
print('Copying data...')
cur.execute('''
    INSERT INTO audio_features_indexed (
        id,
        analysis_url,
        loudness,
        tempo,
        time_signature,
        key,
        mode,
        acousticness,
        danceability,
        energy,
        instrumentalness,
        liveness,
        speechiness,
        valence
    )
    SELECT
        id,
        analysis_url,
        loudness,
        tempo,
        time_signature,
        key,
        mode,
        acousticness,
        danceability,
        energy,
        instrumentalness,
        liveness,
        speechiness,
        valence
    FROM
        audio_features
''')
print('Indexing table...')
cur.execute('CREATE UNIQUE INDEX indexed_analysis_url ON audio_features_indexed(analysis_url)')
cur.execute('CREATE INDEX indexed_loudness ON audio_features_indexed(loudness)')
cur.execute('CREATE INDEX indexed_tempo ON audio_features_indexed(tempo)')
cur.execute('CREATE INDEX indexed_time_signature ON audio_features_indexed(time_signature)')
cur.execute('CREATE INDEX indexed_key ON audio_features_indexed(key)')
cur.execute('CREATE INDEX indexed_mode ON audio_features_indexed(mode)')
cur.execute('CREATE INDEX indexed_acousticness ON audio_features_indexed(acousticness)')
cur.execute('CREATE INDEX indexed_danceability ON audio_features_indexed(danceability)')
cur.execute('CREATE INDEX indexed_energy ON audio_features_indexed(energy)')
cur.execute('CREATE INDEX indexed_instrumentalness ON audio_features_indexed(instrumentalness)')
cur.execute('CREATE INDEX indexed_liveness ON audio_features_indexed(liveness)')
cur.execute('CREATE INDEX indexed_speechiness ON audio_features_indexed(speechiness)')
cur.execute('CREATE INDEX indexed_valence ON audio_features_indexed(valence)')
con.commit()

# Clean up
print('\nCleaning up database...')
cur.execute('VACUUM')
con.commit()

cur.close()
con.close()
# Out:
# Resetting database to initial state...
#
# artists_indexed
# Copying data...
# Indexing table...
#
# albums_indexed
# Copying data...
# Indexing table...
#
# tracks_indexed
# Copying data...
# Indexing table...
#
# audio_features_indexed
# Copying data...
# Indexing table...
#
# Cleaning up database...
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 197
#     195 # Clean up
#     196 print('\nCleaning up database...')
# --> 197 cur.execute('VACUUM')
#     198 con.commit()
#     200 cur.close()
#
# OperationalError: database or disk is full

# %%
con = sqlite3.connect(f'file:{PATH_DB}?mode=ro', uri=True)
df_db = pd.read_sql_query('''
    SELECT
        name, sql
    FROM
        sqlite_master
''', con)
con.close()
# View database after optimization
df_db
# Out:
#                                          name  \
# 0                                      albums
# 1                                     artists
# 2                              audio_features
# 3                                      genres
# 4                            r_albums_artists
# 5                             r_albums_tracks
# 6                              r_artist_genre
# 7                              r_track_artist
# 8                                      tracks
# 9                             artists_indexed
# 10         sqlite_autoindex_artists_indexed_1
# 11                   idx_artists_indexed_name
# 12              idx_artists_indexed_followers
# 13             idx_artists_indexed_popularity
# 14                             albums_indexed
# 15          sqlite_autoindex_albums_indexed_1
# 16                    idx_albums_indexed_name
# 17              idx_albums_indexed_album_type
# 18            idx_albums_indexed_release_date
# 19              idx_albums_indexed_popularity
# 20                             tracks_indexed
# 21          sqlite_autoindex_tracks_indexed_1
# 22          sqlite_autoindex_tracks_indexed_2
# 23                    idx_tracks_indexed_name
# 24                idx_tracks_indexed_duration
# 25                idx_tracks_indexed_explicit
# 26        idx_tracks_indexed_audio_feature_id
# 27              idx_tracks_indexed_popularity
# 28                     audio_features_indexed
# 29  sqlite_autoindex_audio_features_indexed_1
# 30  sqlite_autoindex_audio_features_indexed_2
# 31                       indexed_analysis_url
# 32                           indexed_loudness
# 33                              indexed_tempo
# 34                     indexed_time_signature
# 35                                indexed_key
# 36                               indexed_mode
# 37                       indexed_acousticness
# 38                       indexed_danceability
# 39                             indexed_energy
# 40                   indexed_instrumentalness
# 41                           indexed_liveness
# 42                        indexed_speechiness
# 43                            indexed_valence
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                         sql
# 0                                                                                                                                                                                                                                                                                                                                                             CREATE TABLE albums ([id], [name], [album_group], [album_type], [release_date], [popularity])
# 1                                                                                                                                                                                                                                                                                                                                                                                            CREATE TABLE artists ([name], [id], [popularity], [followers])
# 2                                                                                                                                                                                                                                  CREATE TABLE audio_features ([id], [acousticness], [analysis_url], [danceability], [duration], [energy], [instrumentalness], [key], [liveness], [loudness], [mode], [speechiness], [tempo], [time_signature], [valence])
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                CREATE TABLE genres ([id])
# 4                                                                                                                                                                                                                                                                                                                                                                                                   CREATE TABLE r_albums_artists ([album_id], [artist_id])
# 5                                                                                                                                                                                                                                                                                                                                                                                                     CREATE TABLE r_albums_tracks ([album_id], [track_id])
# 6                                                                                                                                                                                                                                                                                                                                                                                                     CREATE TABLE r_artist_genre ([genre_id], [artist_id])
# 7                                                                                                                                                                                                                                                                                                                                                                                                     CREATE TABLE r_track_artist ([track_id], [artist_id])
# 8                                                                                                                                                                                                                                                                                                 CREATE TABLE tracks ([id], [disc_number], [duration], [explicit], [audio_feature_id], [name], [preview_url], [track_number], [popularity], [is_playable])
# 9                                                                                                                                                                                                                                                                                         CREATE TABLE artists_indexed (\n        id TEXT PRIMARY KEY,\n        name TEXT NOT NULL,\n        followers INTEGER,\n        popularity INTEGER NOT NULL\n    )
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                     None
# 11                                                                                                                                                                                                                                                                                                                                                                                           CREATE INDEX idx_artists_indexed_name ON artists_indexed(name)
# 12                                                                                                                                                                                                                                                                                                                                                                                 CREATE INDEX idx_artists_indexed_followers ON artists_indexed(followers)
# 13                                                                                                                                                                                                                                                                                                                                                                               CREATE INDEX idx_artists_indexed_popularity ON artists_indexed(popularity)
# 14                                                                                                                                                                                                                                                               CREATE TABLE albums_indexed (\n        id TEXT PRIMARY KEY,\n        name TEXT NOT NULL,\n        album_type TEXT,\n        release_date TEXT,\n        popularity INTEGER NOT NULL\n    )
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                     None
# 16                                                                                                                                                                                                                                                                                                                                                                                             CREATE INDEX idx_albums_indexed_name ON albums_indexed(name)
# 17                                                                                                                                                                                                                                                                                                                                                                                 CREATE INDEX idx_albums_indexed_album_type ON albums_indexed(album_type)
# 18                                                                                                                                                                                                                                                                                                                                                                             CREATE INDEX idx_albums_indexed_release_date ON albums_indexed(release_date)
# 19                                                                                                                                                                                                                                                                                                                                                                                 CREATE INDEX idx_albums_indexed_popularity ON albums_indexed(popularity)
# 20                                                                                                                                                                                   CREATE TABLE tracks_indexed (\n        id TEXT PRIMARY KEY,\n        name TEXT NOT NULL,\n        duration INTEGER,\n        explicit INTEGER,\n        audio_feature_id TEXT NOT NULL,\n        popularity INTEGER NOT NULL,\n        UNIQUE(audio_feature_id)\n    )
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                     None
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                     None
# 23                                                                                                                                                                                                                                                                                                                                                                                             CREATE INDEX idx_tracks_indexed_name ON tracks_indexed(name)
# 24                                                                                                                                                                                                                                                                                                                                                                                     CREATE INDEX idx_tracks_indexed_duration ON tracks_indexed(duration)
# 25                                                                                                                                                                                                                                                                                                                                                                                     CREATE INDEX idx_tracks_indexed_explicit ON tracks_indexed(explicit)
# 26                                                                                                                                                                                                                                                                                                                                                              CREATE UNIQUE INDEX idx_tracks_indexed_audio_feature_id ON tracks_indexed(audio_feature_id)
# 27                                                                                                                                                                                                                                                                                                                                                                                 CREATE INDEX idx_tracks_indexed_popularity ON tracks_indexed(popularity)
# 28  CREATE TABLE audio_features_indexed (\n        id TEXT PRIMARY KEY,\n        analysis_url TEXT,\n        loudness REAL,\n        tempo REAL,\n        time_signature INTEGER,\n        key INTEGER,\n        mode INTEGER,\n        acousticness REAL,\n        danceability REAL,\n        energy REAL,\n        instrumentalness REAL,\n        liveness REAL,\n        speechiness REAL,\n        valence REAL,\n        UNIQUE(analysis_url)\n    )
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                     None
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                     None
# 31                                                                                                                                                                                                                                                                                                                                                                         CREATE UNIQUE INDEX indexed_analysis_url ON audio_features_indexed(analysis_url)
# 32                                                                                                                                                                                                                                                                                                                                                                                        CREATE INDEX indexed_loudness ON audio_features_indexed(loudness)
# 33                                                                                                                                                                                                                                                                                                                                                                                              CREATE INDEX indexed_tempo ON audio_features_indexed(tempo)
# 34                                                                                                                                                                                                                                                                                                                                                                            CREATE INDEX indexed_time_signature ON audio_features_indexed(time_signature)
# 35                                                                                                                                                                                                                                                                                                                                                                                                  CREATE INDEX indexed_key ON audio_features_indexed(key)
# 36                                                                                                                                                                                                                                                                                                                                                                                                CREATE INDEX indexed_mode ON audio_features_indexed(mode)
# 37                                                                                                                                                                                                                                                                                                                                                                                CREATE INDEX indexed_acousticness ON audio_features_indexed(acousticness)
# 38                                                                                                                                                                                                                                                                                                                                                                                CREATE INDEX indexed_danceability ON audio_features_indexed(danceability)
# 39                                                                                                                                                                                                                                                                                                                                                                                            CREATE INDEX indexed_energy ON audio_features_indexed(energy)
# 40                                                                                                                                                                                                                                                                                                                                                                        CREATE INDEX indexed_instrumentalness ON audio_features_indexed(instrumentalness)
# 41                                                                                                                                                                                                                                                                                                                                                                                        CREATE INDEX indexed_liveness ON audio_features_indexed(liveness)
# 42                                                                                                                                                                                                                                                                                                                                                                                  CREATE INDEX indexed_speechiness ON audio_features_indexed(speechiness)
# 43                                                                                                                                                                                                                                                                                                                                                                                          CREATE INDEX indexed_valence ON audio_features_indexed(valence)
